# %%
from bs4 import BeautifulSoup
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
from collections import defaultdict

LOCATION = 'html3'

def parse_features(features):
    bedrooms = 0
    bathrooms = 0
    study = False
    parking = 0
    
    for feature in features:
        if 'bed' in feature:
            bedrooms  += int(f'0{replace_all_but(feature, "1234567890")}')
        elif 'bath' in feature:
            bathrooms += int(f'0{replace_all_but(feature, "1234567890")}')
        elif 'park' in feature:
            parking   += int(f'0{replace_all_but(feature, "1234567890")}')
        elif 'study' in feature:
            study = True
     
    return bedrooms, bathrooms, study, parking

def longest_consec_nums(text):
    longest = 0
    curr = 0
    
    for char in text:
        if char.isdigit():
            curr += 1
            longest = max(longest, curr)
        else:
            curr = 0
    
    return longest

def replace_all_but(text, chars):
    new = ''
    for char in text:
        if char in chars:
            new += char
            
    return new

def remove_decimal(num):
    for i in (-3, -2, -1):
        if len(num) < -i:
            continue
        if num[i] in ',.':
            num = num[:i]
            break
    return num

def contains_num(text):
    return any(num in text for num in '1234567890')

def parse_price(text):
    text = text.replace('/', ' ').replace('-', ' ').replace('\\', ' ').replace('~', ' ').replace('$', ' ')
    no_space = text.replace(' ', '')
    
    num_consec_nums = longest_consec_nums(no_space)
    if num_consec_nums <= 2 or num_consec_nums >= 5:
        return np.nan
    
    just_nums = replace_all_but(text, '1234567890,. ')
    nums = just_nums.split()
    nums = [remove_decimal(num) for num in nums]
    nums = [int(num.replace(',', '').replace('.', '')) for num in nums if contains_num(num)]
    
    return max(nums)

# %%
def extract_data(html):
    properties = html.find_all('article')
    data = defaultdict(list)
    
    for prop in properties:
        try:
            info = prop.find_all('div', class_='residential-card__content')[0]
            address = info.find_all('span', class_='')[0].text
        except:
            # If we can't get address or info, then continue 
            continue
            
        try:
            price = info.find_all('span', class_='property-price')[0].text
        except:
            price = np.nan
            
        try:
            property_type = info.find_all('span', class_='residential-card__property-type')[0].text
        except:
            property_type = np.nan
            
        try:
            # class_ often changes, but still starts with "View__PropertyDetail-sc"
            feature_bar = prop.find_all('div', class_='View__PropertyDetail-sc-11ysrk6-0 gIMwxl')
            features = [feature['aria-label'] for feature in feature_bar]
        except:
            features = []  
            
        try:
            url = 'https://www.realestate.com.au' + prop.find_all('a')[0]['href']
        except:
            url = ''
            
        bedrooms, bathrooms, study, parking = parse_features(features)
            
        address = address.replace(',,', ',').split(',')
        data['address'].append(''.join(address[:-1]).strip())
        data['suburb'].append(address[-1].strip())
        data['price'].append(parse_price(price))
        data['property_type'].append(property_type.strip())
        data['bedrooms'].append(bedrooms)
        data['bathrooms'].append(bathrooms)
        data['study'].append(study)
        data['parking'].append(parking)
        data['url'].append(url)
        
    return data

# %%
dicts = []

all_html = os.listdir(LOCATION)
for filename in tqdm(all_html):
    with open(f'{LOCATION}/{filename}', encoding='utf-8') as fp:
        text = fp.read()
        html = BeautifulSoup(text, 'html.parser')
        dicts.append(extract_data(html))
        
data = pd.concat(map(pd.DataFrame, dicts)).reset_index(drop=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 98/98 [00:13<00:00,  7.53it/s]

# %%
data.to_csv('data3.csv', index=False)

# %%
data[((data.bedrooms > 1) | (data.study == True)) & data.price.notna() & (data.price < 750)].sort_values('price').tail(30)
# Out:
#                            address           suburb  price property_type  \
# 2069           10/17 Mosman Street           Mosman  725.0     Apartment
# 891        14.01/1A  Lawson Square          Redfern  725.0     Apartment
# 508             146/267 Bulwara Rd           Ultimo  725.0     Apartment
# 480            41/1-35 Pine Street      Chippendale  725.0     Apartment
# 1815         2/143 Willoughby Road        Naremburn  725.0          Unit
# 1159     1/502 New South Head Road       Double Bay  725.0     Apartment
# 892        10.06/1A  Lawson Square          Redfern  725.0     Apartment
# 1508             106/2 Barr Street       Camperdown  730.0     Apartment
# 2151             50/10 Drovers Way        Lindfield  730.0     Apartment
# 966                28/69 Cook Road  Centennial Park  730.0     Apartment
# 2120          4/21-31 Young Street      Neutral Bay  730.0          Unit
# 2095          4/21-31 Young Street      Neutral Bay  730.0          Unit
# 1440           214/23 Corunna Road         Stanmore  730.0          Unit
# 513               87/209 Harris St          Pyrmont  730.0     Apartment
# 1917  Address available on request      St Leonards  730.0     Apartment
# 1855          6/19 Glenmore Street        Naremburn  730.0     Apartment
# 747          134A O'riordan Street           Mascot  730.0     Apartment
# 2057        2/13 Montpelier Street      Neutral Bay  730.0     Apartment
# 1334            43/150 Wigram Road     Forest Lodge  735.0     Apartment
# 2288       65/27 Bennelong Parkway  Wentworth Point  735.0     Apartment
# 207        309/1 Magdalene Terrace      Wolli Creek  740.0     Apartment
# 16     1B/887 South Dowling Street         Waterloo  740.0     Apartment
# 142            18/15 Bidjigal Road        Arncliffe  740.0     Apartment
# 2133              33/6 Drovers Way        Lindfield  740.0     Apartment
# 760    1B/887 South Dowling Street         Waterloo  740.0     Apartment
# 1330             9/153 Bridge Road            Glebe  740.0       Terrace
# 1210       106/130 Carillon Avenue          Newtown  745.0     Apartment
# 1891                15 Herbert St.      St Leonards  745.0     Apartment
# 1733        4/118 Sailors Bay Road      Northbridge  749.0          Unit
# 806         4/118 Sailors Bay Road      Northbridge  749.0          Unit
#
#       bedrooms  bathrooms  study  parking  \
# 2069         2          1  False        1
# 891          1          2   True        0
# 508          2          1  False        1
# 480          2          1  False        1
# 1815         2          1  False        2
# 1159         2          1  False        0
# 892          1          2   True        0
# 1508         2          1   True        1
# 2151         2          2  False        1
# 966          2          1  False        1
# 2120         1          2   True        1
# 2095         1          2   True        1
# 1440         2          2  False        1
# 513          2          2  False        1
# 1917         2          1  False        0
# 1855         2          2  False        1
# 747          1          1   True        0
# 2057         2          1  False        0
# 1334         2          1  False        1
# 2288         2          2  False        1
# 207          2          1   True        1
# 16           1          1   True        1
# 142          2          2  False        1
# 2133         2          2  False        1
# 760          1          1   True        1
# 1330         2          1   True        0
# 1210         2          2  False        1
# 1891         2          2  False        1
# 1733         2          1  False        2
# 806          2          1  False        2
#
#                                                     url
# 2069  https://www.realestate.com.au/property-apartme...
# 891   https://www.realestate.com.au/property-apartme...
# 508   https://www.realestate.com.au/property-apartme...
# 480   https://www.realestate.com.au/property-apartme...
# 1815  https://www.realestate.com.au/property-unit-ns...
# 1159  https://www.realestate.com.au/property-apartme...
# 892   https://www.realestate.com.au/property-apartme...
# 1508  https://www.realestate.com.au/property-apartme...
# 2151  https://www.realestate.com.au/property-apartme...
# 966   https://www.realestate.com.au/property-apartme...
# 2120  https://www.realestate.com.au/property-unit-ns...
# 2095  https://www.realestate.com.au/property-unit-ns...
# 1440  https://www.realestate.com.au/property-unit-ns...
# 513   https://www.realestate.com.au/property-apartme...
# 1917  https://www.realestate.com.au/property-apartme...
# 1855  https://www.realestate.com.au/property-apartme...
# 747   https://www.realestate.com.au/property-apartme...
# 2057  https://www.realestate.com.au/property-apartme...
# 1334  https://www.realestate.com.au/property-apartme...
# 2288  https://www.realestate.com.au/property-apartme...
# 207   https://www.realestate.com.au/property-apartme...
# 16    https://www.realestate.com.au/property-apartme...
# 142   https://www.realestate.com.au/property-apartme...
# 2133  https://www.realestate.com.au/property-apartme...
# 760   https://www.realestate.com.au/property-apartme...
# 1330  https://www.realestate.com.au/property-terrace...
# 1210  https://www.realestate.com.au/property-apartme...
# 1891  https://www.realestate.com.au/property-apartme...
# 1733  https://www.realestate.com.au/property-unit-ns...
# 806   https://www.realestate.com.au/property-unit-ns...
